# %%
import numpy as np
import pandas as pd
import os
import googlemaps
from google.cloud import bigquery
import requests
import json
import string

# %%
def df_read_files(**kwargs):
    file = input("Enter file name: ")
    os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = file
    
    if '.parquet' in file:
        data = pd.read_parquet(file, engine = 'pyarrow')
    elif '.csv' in file:
        data = pd.read_csv(file)
    elif '.json' in file:
        project_id = input("enter project ID: ")
        bigquery_client = bigquery.Client(project = project_id)
        table_id = input("enter table ID from Big Query: ")
        QUERY = "SELECT * FROM " +  "`" + table_id + "`"
        job = bigquery_client.query(QUERY)
        data = job.to_dataframe()
        
    return data

df = df_read_files()
# Out:
# Enter file name: bcx-insights-6dfb9fabfb5b.json
# enter project ID: bcx-insights
# enter table ID from Big Query: bcx_networkhealth.addresses_20191029

# %%
df.head()
# Out:
#    ENTITYID                             STREETBOX  \
# 0    183627                  100 Brakfontein Road
# 1    461123                     5 Simmonds Street
# 2    181822  C/o Shepstone Street and Collis Road
# 3    283018                        5 Bauhinia Str
# 4    297531                           8 Grix Road
#
#                        SUBURBCITY POSTALCODE CAREOF  \
# 0            Loulardia, Centurion       None   None
# 1      Marshalltown, Johannesburg       None   None
# 2                          Ivongo       None   None
# 3  Highveld Technopark, Centurion       None   None
# 4                Pietermaritzburg       None   None
#
#                            BUILDING      FLOOR  ROOM LATITUDE LONGITUDE  \
# 0            Shopite corporate park       None  None     None      None
# 1              Standard Bank Centre       None  None     None      None
# 2                1861 Rear Building       None  None     None      None
# 3          22 Cambridge Office Park  1st Floor  None     None      None
# 4  Subdivision 9 (of 4) of Lot 122,       None  None     None      None
#
#         PROVINCE
# 0        Gauteng
# 1        Gauteng
# 2  KwaZulu-Natal
# 3           None
# 4           None

# %%
df.tail()
# Out:
#        ENTITYID                           STREETBOX  \
# 26529     33959  Marabastad Informal Trading Market
# 26530    336483                            Erf 3080
# 26531     59858            27 Murrayfield Boulevard
# 26532    191114                 Cnr R51 and Brizial
# 26533    437784                         PO BOX 7655
#
#                                              SUBURBCITY  \
# 26529       11th Street in Junction Street mogul Street
# 26530                    Cnr Heidelberg & Airport Roads
# 26531  Pretoria - Silverlakes -  Homeowners Association
# 26532                                     Daveyton, Jhb
# 26533                                          Pretoria
#
#                                          POSTALCODE CAREOF BUILDING FLOOR  \
# 26529                          Marabastad :Pretoria   None     None  None
# 26530                        Dalpark Ext 5, Brakpan   None     None  None
# 26531                      Management Centre   0081   None     None  None
# 26532           Boyas View North UJ Campus Daveyton   None     None  None
# 26533  speedpot@icon.co.za(Send invoices via email)   None     None  None
#
#            ROOM LATITUDE LONGITUDE PROVINCE
# 26529      None     None      None     None
# 26530  Shop 111     None      None     None
# 26531      None     None      None     None
# 26532     no 90     None      None     None
# 26533      None     None      None  Gauteng

# %%
def load_config(file):
    with open(file) as conf:
        config = json.load(conf)
    return config

# %%
def configure_table(df):
    '''This function uses configuration json files and tunes/formats the input DataFrame to a desired Format'''
    
    
    config = load_config(file) #save config file in variable
    df = df.copy() 
    df.replace(config['null'], '', inplace=True) 
    
    input_cols = df.columns.to_list()
    conf_vals = list(config.values())
    
    #drop unwanted columns
    for i in input_cols:
        if i not in conf_vals:
            df.drop(i, axis=1, inplace=True)
    
    #Get key value pairs in dictionary in a tuple format
    pairs = list(config.items())
    
    #For loop to either rename columns, create new and fill with empty string, or create address column
    for i in pairs:
        if i[1] in input_cols:
            df.rename(columns={i[1]:i[0]}, inplace=True)
        elif i[1] == '':
            df[i[0]] = i[1]
        elif i[0] == 'Address':
            address = []
            keys = list(config.keys())
            input_addr = config['Address']
            for x in input_addr:
                for y in conf_vals:
                    if x == y:
                        address.append(keys[conf_vals.index(y)])
              
            df[i[0]] = [str(a).join([' ' + str(b) + ', ' + str(c)]) for a,b,c in zip(df[address[0]],df[address[1]],df[address[2]])]
            
    # Make sure all nans are changed to empty strings        
    df.replace(np.nan, '', inplace=True)
    
    # Change table order
    output_cols = list(config.keys())[:-1]
    data = df[output_cols]
    
    
    return data

# %%
file = input("Input json file to configure Dataframe ")
# Out:
# Input json file to configure Dataframe config2.json

# %%
#cf = load_config(file)

# %%
dfc = configure_table(df)
dfc.head(10)
# Out:
#        ID Country       Province Postal Code City  \
# 0  183627                Gauteng
# 1  461123                Gauteng
# 2  181822          KwaZulu-Natal
# 3  283018
# 4  297531
# 5   67977
# 6  372671
# 7  445339
# 8  458160                Gauteng
# 9  234524
#
#                            Suburb                                Street  \
# 0            Loulardia, Centurion                  100 Brakfontein Road
# 1      Marshalltown, Johannesburg                     5 Simmonds Street
# 2                          Ivongo  C/o Shepstone Street and Collis Road
# 3  Highveld Technopark, Centurion                        5 Bauhinia Str
# 4                Pietermaritzburg                           8 Grix Road
# 5            Laser Park, Honeydew                            Zeiss Road
# 6               Rosebank, Gauteng                        51 Bath Avenue
# 7             Centurion, Pretoria   5 BauhiniaRoad, Highveld Technopark
# 8   Highveld Technopark Centurion                      5 Bauhinia Road,
# 9                  Foreshore, Cpt          14 Christiaan Barnard Street
#
#   Number                             Building      Floor             Room  \
# 0                      Shopite corporate park
# 1                        Standard Bank Centre
# 2                          1861 Rear Building
# 3                    22 Cambridge Office Park  1st Floor
# 4            Subdivision 9 (of 4) of Lot 122,
# 5                    Kimbuilt Industrial Park             Block B Unit 10
# 6                               Rosebank Mall                Shop 327/328
# 7         Cambridge Office Park - Building 17  1st floor
# 8           Building 22 Cambridge Office Park
# 9                             Atlantic Centre
#
#   Latitude Longitude                                            Address
# 0                            100 Brakfontein Road, Loulardia, Centurion
# 1                         5 Simmonds Street, Marshalltown, Johannesburg
# 2                          C/o Shepstone Street and Collis Road, Ivongo
# 3                        5 Bauhinia Str, Highveld Technopark, Centurion
# 4                                         8 Grix Road, Pietermaritzburg
# 5                                      Zeiss Road, Laser Park, Honeydew
# 6                                     51 Bath Avenue, Rosebank, Gauteng
# 7                      5 BauhiniaRoad, Highveld Technopark, Centurio...
# 8                       5 Bauhinia Road,, Highveld Technopark Centurion
# 9                          14 Christiaan Barnard Street, Foreshore, Cpt

# %%
dfc.tail(10)
# Out:
#            ID Country      Province  \
# 26524  446397          Eastern Cape
# 26525   75876
# 26526  278684
# 26527   52642
# 26528  426401
# 26529   33959
# 26530  336483
# 26531   59858
# 26532  191114
# 26533  437784               Gauteng
#
#                                         Postal Code City  \
# 26524                                Port Elizabeth
# 26525                                port elizabeth
# 26526                               Pan Africa Mall
# 26527                              Cape Town - 8001
# 26528                              Postnetsuit 4529
# 26529                          Marabastad :Pretoria
# 26530                        Dalpark Ext 5, Brakpan
# 26531                      Management Centre   0081
# 26532           Boyas View North UJ Campus Daveyton
# 26533  speedpot@icon.co.za(Send invoices via email)
#
#                                                  Suburb  \
# 26524                                          Lorraine
# 26525                                            walmer
# 26526                                         Alexandra
# 26527                                    Table Mountain
# 26528                                        Rustenburg
# 26529       11th Street in Junction Street mogul Street
# 26530                    Cnr Heidelberg & Airport Roads
# 26531  Pretoria - Silverlakes -  Homeowners Association
# 26532                                     Daveyton, Jhb
# 26533                                          Pretoria
#
#                                    Street Number Building Floor      Room  \
# 26524                  193 Circular Drive
# 26525                     20 sixth avenue
# 26526     Cnr 2nd avenue and Watt  Street                        Shop L/7
# 26527               Table Mountain On top
# 26528                       P.O.BOX 82323
# 26529  Marabastad Informal Trading Market
# 26530                            Erf 3080                        Shop 111
# 26531            27 Murrayfield Boulevard
# 26532                 Cnr R51 and Brizial                           no 90
# 26533                         PO BOX 7655
#
#       Latitude Longitude                                            Address
# 26524                                          193 Circular Drive, Lorraine
# 26525                                               20 sixth avenue, walmer
# 26526                            Cnr 2nd avenue and Watt  Street, Alexandra
# 26527                                 Table Mountain On top, Table Mountain
# 26528                                             P.O.BOX 82323, Rustenburg
# 26529                      Marabastad Informal Trading Market, 11th Stre...
# 26530                              Erf 3080, Cnr Heidelberg & Airport Roads
# 26531                      27 Murrayfield Boulevard, Pretoria - Silverla...
# 26532                                    Cnr R51 and Brizial, Daveyton, Jhb
# 26533                                                 PO BOX 7655, Pretoria
