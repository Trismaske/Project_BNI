# %% [markdown]
# # Introduction

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from pandas.io import gbq
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import date
import datetime
import requests
import json
import time

# %% [markdown]
# # Input

# %%
query = 'SELECT * FROM [bcx-insights.bcx_networkhealth.addresses_20191029]'
df = pd.read_gbq(query, project_id = 'bcx-insights')

# %%
df.head()
# Out:
#    ENTITYID                  STREETBOX            SUBURBCITY POSTALCODE  \
# 0     67977                 Zeiss Road  Laser Park, Honeydew       None
# 1    372671             51 Bath Avenue     Rosebank, Gauteng       None
# 2    155843  90 William Campbell Drive      La Lucia, Durban       None
# 3    351086            Woodlands Drive            Hurlingham       None
# 4     13831           Don Carster Road        Kenilworth. CT       None
#
#   CAREOF                  BUILDING FLOOR              ROOM LATITUDE LONGITUDE  \
# 0   None  Kimbuilt Industrial Park  None   Block B Unit 10     None      None
# 1   None             Rosebank Mall  None      Shop 327/328     None      None
# 2   None             La Lucia Mall  None          Shop 109     None      None
# 3   None    Hurlingham Office Park  None  Floor 1, Block F     None      None
# 4   None         Kenelworth Centre  None        Shop 46/47     None      None
#
#   PROVINCE
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None

# %%
df.shape
# Out:
# (26534, 11)

# %% [markdown]
# # Formatting

# %%
def format_table(df):
    new_cols = ['Number','Street','Suburb','Country']
    for i in new_cols:
        df[i] = None
    
    df['Street'] = df['STREETBOX']
    df['City'] = df['SUBURBCITY']
    df['Postal Code'] = df['POSTALCODE']
    df['Building'] = df['BUILDING']
    df['Floor'] = df['FLOOR']
    df['Room'] = df['ROOM']
    df['Province'] = df['PROVINCE']
    df['Latitude'] = df['LATITUDE']
    df['Longitude'] = df['LONGITUDE']
    df = df[['Country','Province','City','Suburb','Street','Number','Postal Code','Building','Floor','Room','Latitude','Longitude']]
    return df

# %%
df = format_table(df)

# %%
df = df.iloc[0:20].copy()

# %%
df.shape
# Out:
# (20, 12)

# %% [markdown]
# # Get Place Details

# %%
class GooglePlaces(object):
    def __init__(self, apiKey):
        super(GooglePlaces, self).__init__()
        self.apiKey = apiKey
 
    def get_place_details_using_address(self,address):
        endpoint_url = "https://maps.googleapis.com/maps/api/geocode/json"
        
        params = {
            'bounds':'South Africa',
            'address': address,
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        res =  json.loads(res.content)
        results = res['results'][0]
        return results
    
    def get_place_details_using_coordinates(self,coordinates):
        endpoint_url = "https://maps.googleapis.com/maps/api/geocode/json"

        params = {
            'bounds':'South Africa',
            'latlng': coordinates,
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        res =  json.loads(res.content)
        results = res['results']
        return results
#create instance of class and pass api to constructor
gp = GooglePlaces('AIzaSyDE8PAqFBYE4mHrLm7HgPRcoYnZbVjrVQo')

# %% [markdown]
# # Extract Values From Results

# %%
def get_values(d):
    
    """
    This function takes the results from the API request, searches it then extracts certain values and stores in a list.
    
    """
   
    # new dictionary
    values = {}
        
    # length of the address components dictionary in the API results
    count = len(d['address_components']) - 1

    
    #loop through the items in address components to create a new dictionary
    while count >= 0:
        
        values.update({d['address_components'][count]['types'][0]: d['address_components'][count]['long_name'].upper()})
        count = count -1

    results = []
    
    #get country
    results.append(values.get('country',np.nan))
    
    #get province
    results.append(values.get('administrative_area_level_1',np.nan))
    
    #get city
    if 'administrative_area_level_2' in values.keys() and 'locality' in values.keys():
        results.append(values.get('locality',np.nan))
    else:
        results.append(values.get('administrative_area_level_2',np.nan))
    #get suburb
    results.append(values.get('political',np.nan))
    
    #get street
    results.append(values.get('route',np.nan))
    
    #get number
    results.append(values.get('street_number',np.nan))
    
    #get code
    results.append(values.get('postal_code',np.nan)) 

    #get lat
    results.append(d['geometry']['location']['lat'])
    
    #get lng
    results.append(d['geometry']['location']['lng'])
    


    return results

# %% [markdown]
# # Fill Missing Values

# %%
  
def fill_missing(dataframe,instance):
    
    
    index = 0
    cols = dataframe.columns.tolist()
    while index < len(dataframe):

        row = dataframe.iloc[index]

        # get address details from dataframe
        subset = row.copy()
        subset = subset[['Street','City','Building']]
        subset_cols = ['Street','City','Building']

        address  = ""

        for s_col in subset_cols:
            if pd.notnull(subset[s_col]):
                address += subset[s_col]+" "

        # call get_details function
        results = instance.get_place_details_using_address(address)


        #get results of the geocode api request
        values = get_values(results)
        values.insert(7,row.Building.upper())
        values.insert(8,row.Floor)
        values.insert(9,row.Room.upper())

        #create dataframe with API results
        frame = pd.DataFrame(columns = cols, data = [values])

        row_2 = frame.iloc[0]


        for col in cols:

            # check for nulls in the results of api request and change it to the value column
            if pd.isnull(row_2[col]):
                row_2[col] = row[col]

            # check for nulls and mismatch values in dataframe row and replace wiith results of api 
            if row[col] != row_2[col]:
                row[col] = row_2[col]

        #update row in dataframe
        dataframe.iloc[index] = row

        #increment index
        index += 1
    
    return dataframe
fill_missing(df,gp)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          Country       Province                        City  \
# 0   SOUTH AFRICA        GAUTENG                  ROODEPOORT
# 1   SOUTH AFRICA        GAUTENG                JOHANNESBURG
# 2   SOUTH AFRICA  KWAZULU-NATAL                      DURBAN
# 3   SOUTH AFRICA        GAUTENG                     SANDTON
# 4   SOUTH AFRICA   WESTERN CAPE                   CAPE TOWN
# 5   SOUTH AFRICA        GAUTENG                    PRETORIA
# 6   SOUTH AFRICA   EASTERN CAPE              PORT ELIZABETH
# 7   SOUTH AFRICA           None             Ballito, Durban
# 8   SOUTH AFRICA     FREE STATE                BLOEMFONTEIN
# 9   SOUTH AFRICA           None                     Midrand
# 10  SOUTH AFRICA           None       Marabastad , Pretoria
# 11  SOUTH AFRICA   WESTERN CAPE                   CAPE TOWN
# 12  SOUTH AFRICA  KWAZULU-NATAL            PIETERMARITZBURG
# 13  SOUTH AFRICA        GAUTENG                     SANDTON
# 14  SOUTH AFRICA           None                       Parow
# 15  SOUTH AFRICA        GAUTENG                   CENTURION
# 16  SOUTH AFRICA        GAUTENG                     SANDTON
# 17  SOUTH AFRICA        GAUTENG                  ROODEPOORT
# 18  SOUTH AFRICA           None  Mitchells Plain, Cape Town
# 19  SOUTH AFRICA        GAUTENG                JOHANNESBURG
#
#                   Suburb                      Street Number Postal Code  \
# 0             LASER PARK                  ZEISS ROAD      9        2040
# 1               ROSEBANK                 BATH AVENUE     50        2196
# 2               LA LUCIA      WILLIAM CAMPBELL DRIVE     90        4051
# 3             HURLINGHAM            WOODLANDS AVENUE     59        2196
# 4             KENILWORTH              DONCASTER ROAD      1        7708
# 5       PRETORIA CENTRAL                JOUBERT ROAD     12        0002
# 6               FAIRVIEW  WILLIAM MOFFETT EXPRESSWAY   None        6070
# 7                BALLITO               LEONORA DRIVE   None        4399
# 8              PARK WEST        Nelson Mandela Drive   None        9301
# 9            RANDJESPARK                 GEORGE ROAD    399        1683
# 10                  None            Off Mogul Street   None        0002
# 11             CLAREMONT                   MAIN ROAD    120        7735
# 12             WOODLANDS              SANCTUARY ROAD     50        3201
# 13             SANDHURST                RIVONIA ROAD     83        2196
# 14           PLATTEKLOOF         BARONETCY BOULEVARD   None        7500
# 15  HIGHVELD TECHNO PARK             BAUHINIA STREET      5        0157
# 16              WOODMEAD     WATERVAL CRESCENT SOUTH      1        2191
# 17            LASER PARK                  ZEISS ROAD      9        2040
# 18                  None  cnr Az Berman & Morgenster   None        7798
# 19              ROSEBANK              CRADOCK AVENUE    15A        2196
#
#                              Building Floor              Room Latitude  \
# 0            KIMBUILT INDUSTRIAL PARK  None   BLOCK B UNIT 10 -26.0776
# 1                       ROSEBANK MALL  None      SHOP 327/328 -26.1465
# 2                       LA LUCIA MALL  None          SHOP 109 -29.7538
# 3              HURLINGHAM OFFICE PARK  None  FLOOR 1, BLOCK F -26.0893
# 4                   KENELWORTH CENTRE  None        SHOP 46/47  -33.989
# 5       UNISA SUNNYSIDE CAMPUS HALL B  None          CASHIERS -25.7585
# 6                 MOFFETT RETAIL PARK  None           SHOP 1A -33.9572
# 7   BALLITO JUNCTION SHOPPING  CENTRE  None                G1 -29.5263
# 8        GEORGE DU TOIT BUILDING, UFS  None          ROOM 205 -29.1119
# 9                           MIFA PARK  None           UNIT 18 -25.9634
# 10          MARABASTAD ORIENTAL PLAZA  None     SHOP C10 - 11 -25.7391
# 11             STANDARD BANK GALLERIA  None                G1 -33.9804
# 12              LIBERTY MIDLANDS MALL  None          SHOP 102 -29.5823
# 13                SANDTON CITY OFFICE  None          LEVEL 19 -26.1093
# 14         PLATTEKLOOF VILLAGE CENTRE  None           SHOP 29 -33.8655
# 15              CAMBRIDGE OFFICE PARK  None       BUILDING 22 -25.8811
# 16               WOODMEAD RETAIL PARK  None          SHOP 598 -26.0499
# 17            KIMBURT INDUSTRIAL PARK  None          UNIT B10 -26.0776
# 18             LIBERTY PROMENADE MALL  None               196 -34.0398
# 19               THE MALL OF ROSEBANK  None               165 -26.1464
#
#    Longitude
# 0     27.915
# 1    28.0412
# 2    31.0646
# 3    28.0232
# 4    18.4851
# 5    28.1982
# 6    25.5544
# 7    31.2036
# 8    26.1891
# 9    28.1349
# 10   28.1747
# 11    18.465
# 12   30.3767
# 13    28.053
# 14   18.5719
# 15   28.1831
# 16   28.0917
# 17    27.915
# 18   18.6146
# 19   28.0415

# %% [markdown]
# # Get Max Distance Neighbours and Same Block Neighbours

# %% [markdown]
# # Output
